# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

from sklearn.preprocessing import LabelEncoder as Enc

# %%
column_names = ['ID', 'age', 'gender', 'education', 'country', 'ethnicity', 'Nscore', 'Escore', 'Oscore', 'Ascore', 'Cscore', 'impulsiveness', 'SS', 'alcohol','amphet','amyl', 'benzos', 'caff', 'cannabis', 'choc', 'coke', 'crack', 'ecstasy', 'heroin', 'ketamine', 'legalh', 'LSD', 'meth', 'mushrooms', 'nicotine', 'semer','VSA']
database = pd.read_csv('drug_consumption.csv', header = None, index_col = 0, names = column_names)
database.head(25)
# Out:
#         age   gender  education  country  ethnicity   Nscore   Escore  \
# ID
# 1   0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 2  -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 3   0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 4  -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 5   0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
# 6   2.59171  0.48246   -1.22751  0.24923   -0.31685 -0.67825 -0.30033
# 7   1.09449 -0.48246    1.16365 -0.57009   -0.31685 -0.46725 -1.09207
# 8   0.49788 -0.48246   -1.73790  0.96082   -0.31685 -1.32828  1.93886
# 9   0.49788  0.48246   -0.05921  0.24923   -0.31685  0.62967  2.57309
# 10  1.82213 -0.48246    1.16365  0.96082   -0.31685 -0.24649  0.00332
# 11 -0.07854  0.48246    0.45468  0.96082   -0.31685 -1.05308  0.80523
# 12  1.09449 -0.48246   -0.61113 -0.28519   -0.31685 -1.32828  0.00332
# ...

# %%
import math

# %%
transform_sex = {
    'F': -1,
    'M': 1
}

gender_transform = lambda x: int(x / math.fabs(x))
database['gender'] = database['gender'].apply(gender_transform)

# %%
database.head(25)
# Out:
#         age  gender  education  country  ethnicity   Nscore   Escore   Oscore  \
# ID
# 1   0.49788       1   -0.05921  0.96082    0.12600  0.31287 -0.57545 -0.58331
# 2  -0.07854      -1    1.98437  0.96082   -0.31685 -0.67825  1.93886  1.43533
# 3   0.49788      -1   -0.05921  0.96082   -0.31685 -0.46725  0.80523 -0.84732
# 4  -0.95197       1    1.16365  0.96082   -0.31685 -0.14882 -0.80615 -0.01928
# 5   0.49788       1    1.98437  0.96082   -0.31685  0.73545 -1.63340 -0.45174
# 6   2.59171       1   -1.22751  0.24923   -0.31685 -0.67825 -0.30033 -1.55521
# 7   1.09449      -1    1.16365 -0.57009   -0.31685 -0.46725 -1.09207 -0.45174
# 8   0.49788      -1   -1.73790  0.96082   -0.31685 -1.32828  1.93886 -0.84732
# 9   0.49788       1   -0.05921  0.24923   -0.31685  0.62967  2.57309 -0.97631
# 10  1.82213      -1    1.16365  0.96082   -0.31685 -0.24649  0.00332 -1.42424
# 11 -0.07854       1    0.45468  0.96082   -0.31685 -1.05308  0.80523 -1.11902
# ...
