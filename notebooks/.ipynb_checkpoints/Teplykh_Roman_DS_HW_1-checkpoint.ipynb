# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt

import math

# %% [markdown]
# ## Import data

# %%
test = pd.read_csv('hw1_test.csv')
train = pd.read_csv('hw1_train.csv')

# %%
test.head()
# Out:
#    Target   Time-0    Time-1   Time-2    Time-3   Time-4   Time-5  Time-6  \
# 0      -1 -0.79717 -0.664390 -0.37301  0.040815  0.52694  0.98429  1.3531
# 1       1  0.80485  0.634630  0.37347  0.038343 -0.34099 -0.74086 -1.1097
# 2      -1  0.72799  0.111280 -0.49912 -1.068600 -1.57840 -1.99050 -2.3020
# 3      -1 -0.23444 -0.502160 -0.73249 -0.946130 -1.13970 -1.32330 -1.4902
# 4      -1 -0.17133 -0.062285  0.23583  0.710400  1.24000  1.64980  1.8763
#
#    Time-7  Time-8    ...     Time-490  Time-491  Time-492  Time-493  Time-494  \
# 0  1.5781  1.6593    ...      1.12080  0.722420   0.36207  0.092083 -0.081268
# 1 -1.3954 -1.5702    ...      0.38640  0.049213  -0.25814 -0.510580 -0.683650
# 2 -2.5034 -2.5852    ...      0.39446  0.463680   0.50773  0.517170  0.504590
# 3 -1.6071 -1.6204    ...     -0.95280 -0.929440  -0.92276 -0.929440 -0.909410
# 4  1.8655  1.7038    ...      0.77619  0.725500   0.69745  0.731970  0.808540
#
#    Time-495  Time-496  Time-497  Time-498  Time-499
# 0  -0.21257  -0.39146  -0.66439 -1.073800  -1.56430
# 1  -0.77382  -0.78525  -0.71489 -0.560440  -0.31909
# 2   0.47627   0.43851   0.39446  0.339400   0.25539
# 3  -0.83597  -0.69577  -0.47879 -0.188710   0.11974
# 4   0.83982   0.73305   0.43752 -0.026585  -0.60221
#
# [5 rows x 501 columns]

# %%
train.head(20)
# Out:
#     Target    Time-0    Time-1    Time-2   Time-3    Time-4   Time-5   Time-6  \
# 0       -1 -0.140400  0.171640  0.302040  0.23280  0.033853 -0.22418 -0.46999
# 1       -1  0.334040  0.322250  0.453840  0.67185  0.887900  1.02050  1.05980
# 2       -1  0.716690  0.744370  0.725910  0.66133  0.555220  0.41359  0.24658
# 3        1  1.240300  1.331200  1.386600  1.38320  1.306000  1.14280  0.87861
# 4       -1 -1.159500 -1.204200 -1.167600 -1.03350 -0.818170 -0.55812 -0.29929
# 5        1  0.659020  0.325790  0.019658 -0.22144 -0.393310 -0.51609 -0.60286
# 6       -1 -0.357040 -0.349500 -0.478710 -0.67790 -0.884630 -1.00200 -0.98154
# 7       -1  0.012008  0.759680  1.301100  1.56440  1.511800  1.21680  0.75547
# 8        1 -1.064300 -1.102700 -1.095800 -1.05370 -0.961710 -0.80527 -0.55537
# 9        1 -1.196700 -0.930590 -0.608550 -0.23722  0.177140  0.61496  1.04970
# 10      -1  3.527500  3.102200  2.623700  2.14830  1.701100  1.25070  0.75348
# 11       1 -0.033265  0.250060  0.514420  0.71697  0.823850  0.81315  0.69795
# 12      -1 -0.293000  0.027198  0.455250  0.86009  1.154100  1.30640  1.29590
# 13       1  1.713200  1.618700  1.416900  1.09900  0.673160  0.15667 -0.41370
# 14      -1 -1.423300 -1.622700 -1.705700 -1.65920 -1.506400 -1.27380 -1.00470
# 15       1  1.031000  0.899510  0.669200  0.38519  0.091364 -0.16929 -0.39014
# 16      -1 -0.328010 -0.466660 -0.577320 -0.66664 -0.738630 -0.79729 -0.83729
# 17      -1  1.407900  0.330130 -0.731720 -1.48320 -1.759600 -1.57890 -1.10060
# 18      -1  0.642140  1.306900  1.685700  1.58150  1.032300  0.15729 -0.78495
# 19      -1  0.120290 -0.834410 -1.989900 -2.97850 -3.488700 -3.29740 -2.52140
#
#       Time-7    Time-8    ...     Time-490  Time-491  Time-492  Time-493  \
# 0  -0.645400 -0.617700    ...    -0.319970  0.390900  0.974830  1.258700
# 1   1.030300  0.950750    ...     0.435190 -0.346500 -0.924910 -1.208700
# 2   0.065273 -0.121110    ...     3.171000  2.276000  1.219500  0.081881
# 3   0.532290  0.140020    ...    -0.820260 -1.124600 -1.302000 -1.340600
# 4  -0.093691  0.022770    ...     0.660850  0.441440  0.206180 -0.006941
# 5  -0.661320 -0.706270    ...     0.244420  0.045383 -0.167300 -0.382870
# 6  -0.741430 -0.256900    ...     0.259930  0.418210  0.404210  0.305150
# 7   0.345710  0.032022    ...    -0.736090 -0.503290 -0.338970 -0.278930
# 8  -0.203580  0.204560    ...    -0.878140 -1.131700 -1.259700 -1.253400
# 9   1.444200  1.761800    ...    -0.112640  0.162020  0.423440  0.656310
# 10  0.187720 -0.447460    ...    -1.041700 -1.119900 -1.044800 -0.835270
# 11  0.507820  0.278720    ...     2.105700  1.604100  1.028500  0.411600
# 12  1.169900  1.017600    ...     0.155950  0.202680  0.149650  0.045786
# 13 -0.988460 -1.497300    ...    -0.555290 -0.379330 -0.125700  0.178700
# 14 -0.738860 -0.463080    ...    -0.429850 -0.343470 -0.303930 -0.333500
# 15 -0.577300 -0.753520    ...    -0.449050 -0.309630 -0.110670  0.128800
# 16 -0.847950 -0.826620    ...     0.242590  0.331910  0.409230  0.485220
# 17 -0.557400 -0.140110    ...     0.077153  0.071839 -0.043806 -0.244910
# 18 -1.515100 -1.827600    ...     1.780400  1.922400  1.780400  1.335300
# 19 -1.405200 -0.350740    ...    -0.238060 -0.160460  0.064158  0.418890
#
#     Time-494  Time-495  Time-496  Time-497  Time-498  Time-499
# 0   1.143300  0.647090 -0.049582 -0.690400  -0.97660  -0.79426
# 1  -1.248000 -1.140000 -1.041800 -1.041800  -1.15960  -1.37570
# 2  -1.050300 -2.092900 -2.983300 -3.675300  -4.13660  -4.33960
# 3  -1.271400 -1.146400 -1.011300 -0.931220  -0.93450  -1.00130
# 4  -0.146920 -0.183080 -0.112380  0.008987   0.13141   0.18627
# 5  -0.599150 -0.786110 -0.913570 -0.932320  -0.81169  -0.55159
# 6   0.159800  0.082486  0.122110  0.219020   0.26962   0.19748
# 7  -0.231530 -0.059515  0.343610  0.954550   1.64870   2.14380
# 8  -1.115800 -0.870280 -0.558200 -0.232370   0.06438   0.31117
# 9   0.851930  1.011200  1.128800  1.190100   1.17520   1.06690
# 10 -0.547540 -0.241680  0.045423  0.280610   0.44699   0.55332
# 11 -0.216450 -0.827110 -1.395700 -1.890800  -2.27250  -2.51630
# 12 -0.014914  0.035704  0.236290  0.571290   0.95460   1.32220
# 13  0.488310  0.753080  0.940210  1.041900   1.04760   0.96965
# 14 -0.433180 -0.605950 -0.801990 -0.971440  -1.05780  -1.04450
# 15  0.377090  0.576150  0.689250  0.710400   0.63777   0.48170
# 16  0.561210  0.633210  0.694530  0.733190   0.73586   0.69587
# 17 -0.461740 -0.664760 -0.717900 -0.637120  -0.48725  -0.24491
# 18  0.685700 -0.022822 -0.609760 -1.003700  -1.21200  -1.28780
# 19  0.838780  1.177900  1.337300  1.209800   0.76436   0.12050
#
# [20 rows x 501 columns]

# %% [markdown]
# If one takes a look at average values in each class, it will be easy to see that it is hard to define anything special from this information to select features.

# %%
train.groupby(by='Target').mean()
# Out:
#           Time-0    Time-1    Time-2    Time-3    Time-4    Time-5    Time-6  \
# Target
# -1      0.057578  0.050947  0.037003  0.017715 -0.003280 -0.022263 -0.037115
#  1      0.054322  0.048807  0.040886  0.030842  0.018868  0.005302 -0.008981
#
#           Time-7    Time-8    Time-9    ...     Time-490  Time-491  Time-492  \
# Target                                  ...
# -1     -0.044112 -0.042787 -0.037302    ...     0.018193  0.020474  0.015818
#  1     -0.022347 -0.033974 -0.043031    ...    -0.063421 -0.064323 -0.060269
#
#         Time-493  Time-494  Time-495  Time-496  Time-497  Time-498  Time-499
# Target
# -1      0.006062 -0.005288 -0.015752 -0.022897 -0.025660 -0.025613 -0.023231
#  1     -0.053226 -0.044079 -0.034087 -0.023680 -0.012305  0.000637  0.015415
#
# [2 rows x 500 columns]

# %% [markdown]
# Statistical characteristics of each object in "Time-1" also show nothing.

# %%
time_point = 'Time-1'
train.groupby(by='Target').describe().loc[:,time_point]
# Out:
#         count      mean       std     min       25%       50%     75%     max
# Target
# -1      681.0  0.050947  1.064031 -3.1142 -0.623790  0.025033  0.7433  3.6472
#  1      639.0  0.048807  0.988001 -2.7818 -0.621555  0.089898  0.6291  3.8548

# %% [markdown]
# It is also difficult to divide rows according to their MIN and MAX.

# %%
train.groupby(by='Target').max()
# Out:
#         Time-0  Time-1  Time-2  Time-3  Time-4  Time-5  Time-6  Time-7  \
# Target
# -1      3.9723  3.6472  3.1422  3.3824  3.3737  3.0805  3.2026  3.1492
#  1      3.8879  3.8548  3.5008  3.4252  3.6039  3.4983  3.1249  3.1203
#
#         Time-8  Time-9    ...     Time-490  Time-491  Time-492  Time-493  \
# Target                    ...
# -1      2.9883  2.8145    ...       3.1710    3.0389    2.9774    3.0428
#  1      3.1493  3.0445    ...       2.7138    2.9379    3.3075    3.4406
#
#         Time-494  Time-495  Time-496  Time-497  Time-498  Time-499
# Target
# -1        3.3727    3.8780    4.1307    4.0991    3.7912    3.6966
#  1        3.3108    3.2838    2.9927    2.8813    2.9827    2.9251
#
# [2 rows x 500 columns]

# %%
train.groupby(by='Target').min()
# Out:
#         Time-0  Time-1  Time-2  Time-3  Time-4  Time-5  Time-6  Time-7  \
# Target
# -1     -3.2953 -3.1142 -3.1434 -2.9785 -3.4887 -3.2974 -3.1522 -3.2477
#  1     -3.0384 -2.7818 -3.0333 -3.2101 -3.1332 -3.1694 -3.5306 -3.6141
#
#         Time-8  Time-9    ...     Time-490  Time-491  Time-492  Time-493  \
# Target                    ...
# -1     -3.1522 -2.8441    ...       -2.734   -2.7594   -2.9232   -3.0872
#  1     -3.4991 -3.8918    ...       -3.191   -2.7296   -2.8945   -3.3457
#
#         Time-494  Time-495  Time-496  Time-497  Time-498  Time-499
# Target
# -1       -3.3140   -3.3346   -3.2916   -3.6753   -4.1366   -4.3396
#  1       -3.6407   -3.6445   -3.3234   -2.9735   -3.2466   -3.2481
#
# [2 rows x 500 columns]

# %% [markdown]
# Transforming pd.DataFrame into numpy.array

# %%
test_array = test.get_values()
train_array = train.get_values()

# %%
train_mean = train.groupby(by='Target').mean()
test_mean = test.groupby(by='Target').mean()

# %% [markdown]
# After a closer look on several objects from different classes, it seems possible that they differ by a number of extreme points or period length.

# %%
plt.figure(figsize=(16, 10))
plt.plot(train_array[0, 1:25], 'r', label='1')
plt.plot(train_array[3, 1:25], 'b', label='-1')
plt.plot([0, 25], [0, 0], '--g')
plt.grid()
plt.legend()
plt.show()

# %%
def feat_dist(func, timepoints, values=False, plot=True):
    '''Feature distribution for each class'''
    #feat = func(series)
    if not values and not plot:
        print('Warning: Useless start of feat_dist()')
    
    feat_class_dict = dict()
    for tar in set(train.loc[:,'Target']):
        feat_class_list = list()
        for ind in target_indexes[tar]:
            feat_class_list.append(func(train.loc[ind, timepoints]))
        feat_class_dict[tar]=feat_class_list
        
    if plot:
        for tar in feat_class_dict.keys():
            sns.distplot(feat_class_dict[tar], label=str(tar))
            plt.legend()
    
    if values:
        return feat_class_dict

# %%
plt.figure(figsize=(16, 10))
plt.plot(train_array[0, 1:-1], 'r', label='1')
plt.plot(train_array[3, 1:-1], 'b', label='-1')
plt.plot([0, 500], [0, 0], '--g')
plt.grid()
plt.legend()
plt.title('Objects from different classes')
plt.show()

# %%
target_indexes = dict()
for target in [-1, 1]:
    target_indexes[target] = train[train['Target'] == target].index

# %%
def pretty_plot(y, target, title=None):
    
    'Pretty plot of y data'
    
    plt.plot(y, label = str(target))
    plt.xticks(range(0, len(y), 50))
    plt.xlim(0, len(y))
    
    if title == None:
        title = ''
        
    plt.title(title)
    plt.legend()

# %%
plots_count = 2
plt.figure(figsize=(20,10))

for i in range(int(plots_count)):
    for target in [-1, 1]:
        
        y = train.loc[np.random.choice(target_indexes[target])]
        pretty_plot(y, target=target, title='Objects from different classes')    
        
plt.show()

# %% [markdown]
# #### Divide selection TRAIN into 2 classes

# %%
one = train_array[np.where(train_array[:, 0] == 1), 1:][0]
minus_one = train_array[np.where(train_array[:, 0] == -1), 1:][0]

# %%
plt.figure(figsize=(16, 10))
plt.plot(train_array[0, 1:25], 'r', label='1')
plt.plot(train_array[3, 1:25], 'b', label='-1')
plt.plot([0, 25], [0, 0], '--g')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Choosing the features

# %% [markdown]
# ### Feature 1: number of extreme points of a times series. According to the picture above, it seems that objects from class "-1" period is larger than the same of object from class "1". Therefore, number of extreme points might be the feature.

# %%
def count_extr(series):
    
    'Calculation of extreme points amount in a certain row'
    
    sign_changes = np.sign(np.gradient(series))
    count = 0

    for s_1, s_2 in zip(sign_changes[:-1], sign_changes[1:]):
        if s_1 * s_2 < 0:
            count += 1
            
    return count

# %%
one_count = list()

for row_num in range(one.shape[0]):
    count = count_extr(one[row_num, 1:])
    one_count.append(count)

# %%
minus_one_count = list()

for row_num in range(minus_one.shape[0]):
    count = count_extr(minus_one[row_num, 1:])
    minus_one_count.append(count)

# %%
one_extr_amount = sum(one_count) / len(one_count)
minus_one_extr_amount = sum(minus_one_count) / len(minus_one_count)

# %%
print('Average number of extreme points for objects of class "1" : ', one_extr_amount)
print('Average number of extreme points for objects of class "-1": ', minus_one_extr_amount)
# Out:
# Average number of extreme points for objects of class "1" :  53.76525821596244
# Average number of extreme points for objects of class "-1":  61.19970631424376

# %%
def calc_accuracy(data, mid):
    
    'Verification of accuracy of classification by \\
    calculation of extreme points number and comparison with dividing value '


    ans = list()

    for row_num in range(data.shape[0]):
        content = data[row_num, 1:]
        CLASS = data[row_num, 0]

        count = count_extr(content)
        cl = 0

        if count < mid:
            cl = 1
        else:
            cl = -1

        ans.append( int(CLASS == cl) )

    return sum(ans) / len(ans)

# %% [markdown]
# ####  Selection of an optimal dividing value for a number of extreme points

# %%
correct_ans_train = list()
correct_ans_test = list()

MID_MIN = 45
MID_MAX = 75

for mid in range(MID_MIN, MID_MAX):
    ans = calc_accuracy(train_array, mid)
    correct_ans_train.append(ans)
    
    ans = calc_accuracy(test_array, mid)
    correct_ans_test.append(ans)

# %%
plt.figure(figsize=(16, 10))
plt.plot(correct_ans_train, 'r', label='accuracy_train(mid)')
plt.plot(correct_ans_test, 'b', label='accuracy_test(mid)')
plt.grid()
plt.legend()
plt.show()

# %%
MID_OPTIMAL = 69

# %% [markdown]
# #### It can be seen that accuracy for different classes has an extreme point ~69, optimum number of extremes will be considere 69 further on

# %% [markdown]
# ### Feature 2. Taking the exponent for enlarging the visual difference between row's values

# %%
one_exp = np.exp(one)
minus_one_exp = np.exp(minus_one)

# %%
plt.figure(figsize=(16, 10))
# plt.plot(one_exp[0, 1:], '--r', label='1')
plt.plot(one_exp[3, 1:], 'r', label='1')
# plt.plot(minus_one_exp[0, 1:], '--b', label='-1')
plt.plot(minus_one_exp[1, 1:], 'b', label='-1')
# plt.plot(correct_ans_test, 'b', label='accuracy_test(mid)')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 10))
# plt.plot(one_exp[0, 1:], '--r', label='1')
plt.plot(one_exp[10, 1:], 'r', label='1')
# plt.plot(minus_one_exp[0, 1:], '--b', label='-1')
plt.plot(minus_one_exp[21, 1:], 'b', label='-1')
# plt.plot(correct_ans_test, 'b', label='accuracy_test(mid)')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# #### As one can see, feature 2 does not give any visual pattern so we will consider it inapplicable

# %% [markdown]
# ### Feature 3 Analysis of  variation series

# %%
variation_series_one = np.sort(one)
variation_series_minus_one = np.sort(minus_one)

# %%
plt.figure(figsize=(16, 10))
# plt.plot(variation_series_one[0, 1:], 'g', label='1')
plt.plot(variation_series_one[11, :], 'r', label='1')
# plt.plot(variation_series_minus_one[0, 1:], 'y', label='-1')
plt.plot(variation_series_minus_one[10, :], 'b', label='-1')
# plt.plot(correct_ans_test, 'b', label='accuracy_test(mid)')
plt.grid()
plt.legend()
plt.title('Variation series')
plt.show()

# %%
plt.figure(figsize=(16, 10))
# plt.plot(variation_series_one[0, 1:], 'g', label='1')
plt.plot(variation_series_one[100, :], 'r', label='1')
# plt.plot(variation_series_minus_one[0, 1:], 'y', label='-1')
plt.plot(variation_series_minus_one[120, :], 'b', label='-1')
# plt.plot(correct_ans_test, 'b', label='accuracy_test(mid)')
plt.grid()
plt.legend()
plt.title('Variation series')
plt.show()

# %% [markdown]
# #### Feature 3 also does not give direct results, inapplicable

# %% [markdown]
# ### Feature 4. Expansion into Fourier series (FFT)

# %%
plt.figure(figsize=(25,5))
for tar in [-1, 1]:
    fourier = abs(np.fft.fft(train_mean.loc[tar]))
    plt.title('Absolute values of FT')
    pretty_plot(fourier, str(tar))
    plt.xlim((0,100))

# %% [markdown]
# #### On the picture the Fourier series transformation for mean values is shown. Easy to see that all the peaks are situated between 20 and 60 and classes are visually different and can be divided. We can consider sum of coefficients in Fourier series transformation as a feature and pick out critical values for classification.

# %%
def sum_abs_fft(series):
    '''Sum of abs values of FT for timesteps'''
    
    left = 40
    right = 60
    
    fourier = abs(np.fft.fft(series))[left:right]
    return np.sum(fourier)

# %% [markdown]
# #### After a series of experiments an area for sum calculation was chosen: Time-40 - Time-60

# %%
feat_dist(sum_abs_fft, train.columns[1:])
plt.xlim(0,1000)
# Out:
# (0, 1000)

# %% [markdown]
# #### Distribution of Fourier coefficients sum values for different classes. It is possible to select a tendency or a rule, that: "-1" - (0, 90) and (380, 1000)

# %% [markdown]
# ## Creating the rules and calculation of accuracy with test

# %% [markdown]
# ### As a result, only features 1 and 4 fit. It is necessary to make rules for them, define classes with the help of these rules and count the accuracy

# %%
def ft_feature(series):
    feature = sum_abs_fft(series)
    if feature > 380 or feature < 90:
        return -1
    else:
        return 1

# %%
def extr_rule(series, mid):
    feature = count_extr(series)
    if feature > mid:
        return -1
    else:
        return 1

# %%
for row in test.index:
    test.loc[row,'fft'] = ft_feature(test.loc[row,'Time-0':'Time-499'])
    test.loc[row,'extremals'] = extr_rule(test.loc[row, 'Time-0':'Time-499'], 68)

# %%
fft_feature = accuracy_score(test.Target, list(test.loc[:,'fft']))
extr_feature = accuracy_score(test.Target, list(test.loc[:,'extremals']))

# %%
print('Accuracy extremal feature: {}'.format(extr_feature))
print('Accuracy fft feature: {}'.format(fft_feature))
# Out:
# Accuracy extremal feature: 0.6984171063593446
# Accuracy fft feature: 0.7286864759788948
